# %%
import pandas as pd
import sqlite3 as sl
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from matplotlib import style

df_reviews=pd.read_csv('test.csv')
df=pd.read_csv('train.csv')
df_reviews
# Out:
#        Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 0               0  19556  Female     Loyal Customer   52  Business travel
# 1               1  90035  Female     Loyal Customer   36  Business travel
# 2               2  12360    Male  disloyal Customer   20  Business travel
# 3               3  77959    Male     Loyal Customer   44  Business travel
# 4               4  36875  Female     Loyal Customer   49  Business travel
# ...           ...    ...     ...                ...  ...              ...
# 25971       25971  78463    Male  disloyal Customer   34  Business travel
# 25972       25972  71167    Male     Loyal Customer   23  Business travel
# 25973       25973  37675  Female     Loyal Customer   17  Personal Travel
# 25974       25974  90086    Male     Loyal Customer   14  Business travel
# 25975       25975  34799  Female     Loyal Customer   42  Personal Travel
#
#           Class  Flight Distance  Inflight wifi service  \
# 0           Eco              160                      5
# 1      Business             2863                      1
# 2           Eco              192                      2
# 3      Business             3377                      0
# 4           Eco             1182                      2
# ...         ...              ...                    ...
# 25971  Business              526                      3
# 25972  Business              646                      4
# 25973       Eco              828                      2
# 25974  Business             1127                      3
# 25975       Eco              264                      2
#
#        Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                      4  ...                       5
# 1                                      1  ...                       4
# 2                                      0  ...                       2
# 3                                      0  ...                       1
# 4                                      3  ...                       2
# ...                                  ...  ...                     ...
# 25971                                  3  ...                       4
# 25972                                  4  ...                       4
# 25973                                  5  ...                       2
# 25974                                  3  ...                       4
# 25975                                  5  ...                       1
#
#        On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                     5                 5                 5                2
# 1                     4                 4                 4                3
# 2                     4                 1                 3                2
# 3                     1                 1                 1                3
# 4                     2                 2                 2                4
# ...                 ...               ...               ...              ...
# 25971                 3                 2                 4                4
# 25972                 4                 5                 5                5
# 25973                 4                 3                 4                5
# 25974                 3                 2                 5                4
# 25975                 1                 2                 1                1
#
#        Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                     5            5                          50
# 1                     4            5                           0
# 2                     2            2                           0
# 3                     1            4                           0
# 4                     2            4                           0
# ...                 ...          ...                         ...
# 25971                 5            4                           0
# 25972                 5            4                           0
# 25973                 4            2                           0
# 25974                 5            4                           0
# 25975                 1            1                           0
#
#        Arrival Delay in Minutes             satisfaction
# 0                          44.0                satisfied
# 1                           0.0                satisfied
# 2                           0.0  neutral or dissatisfied
# 3                           6.0                satisfied
# 4                          20.0                satisfied
# ...                         ...                      ...
# 25971                       0.0  neutral or dissatisfied
# 25972                       0.0                satisfied
# 25973                       0.0  neutral or dissatisfied
# 25974                       0.0                satisfied
# 25975                       0.0  neutral or dissatisfied
#
# [25976 rows x 25 columns]

# %%
# shape and data types of the data
print(df.shape)
print(df.dtypes)

# select numeric columns
df_numeric = df.select_dtypes(include=[np.number])
numeric_cols = df_numeric.columns.values
print(numeric_cols)

# select non numeric columns
df_non_numeric = df.select_dtypes(exclude=[np.number])
non_numeric_cols = df_non_numeric.columns.values
print(non_numeric_cols)
# Out:
# (103904, 25)
# Unnamed: 0                             int64
# id                                     int64
# Gender                                object
# Customer Type                         object
# Age                                    int64
# Type of Travel                        object
# Class                                 object
# Flight Distance                        int64
# Inflight wifi service                  int64
# Departure/Arrival time convenient      int64
# Ease of Online booking                 int64
# Gate location                          int64
# Food and drink                         int64
# Online boarding                        int64
# Seat comfort                           int64
# Inflight entertainment                 int64
# On-board service                       int64
# Leg room service                       int64
# Baggage handling                       int64
# Checkin service                        int64
# Inflight service                       int64
# Cleanliness                            int64
# Departure Delay in Minutes             int64
# Arrival Delay in Minutes             float64
# satisfaction                          object
# dtype: object
# ['Unnamed: 0' 'id' 'Age' 'Flight Distance' 'Inflight wifi service'
#  'Departure/Arrival time convenient' 'Ease of Online booking'
#  'Gate location' 'Food and drink' 'Online boarding' 'Seat comfort'
#  'Inflight entertainment' 'On-board service' 'Leg room service'
#  'Baggage handling' 'Checkin service' 'Inflight service' 'Cleanliness'
#  'Departure Delay in Minutes' 'Arrival Delay in Minutes']
# ['Gender' 'Customer Type' 'Type of Travel' 'Class' 'satisfaction']

# %%
#Finding missing values
total_cells = np.product(df.shape)

missing_cells = pd.isnull(df).sum()
#print(missing_cells)

total_missing = missing_cells.sum()
#print(total_missing)

percentage_missing = round((total_missing/total_cells), 2) *100

print(percentage_missing, "% Missing cells from the data")
# Out:
# 0.0 % Missing cells from the data

# %%
#df.columns

# %%
#to find the missing percentages
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100,2)))
# Out:
# Unnamed: 0 - 0.0%
# id - 0.0%
# Gender - 0.0%
# Customer Type - 0.0%
# Age - 0.0%
# Type of Travel - 0.0%
# Class - 0.0%
# Flight Distance - 0.0%
# Inflight wifi service - 0.0%
# Departure/Arrival time convenient - 0.0%
# Ease of Online booking - 0.0%
# Gate location - 0.0%
# Food and drink - 0.0%
# Online boarding - 0.0%
# Seat comfort - 0.0%
# Inflight entertainment - 0.0%
# On-board service - 0.0%
# Leg room service - 0.0%
# Baggage handling - 0.0%
# Checkin service - 0.0%
# Inflight service - 0.0%
# Cleanliness - 0.0%
# Departure Delay in Minutes - 0.0%
# Arrival Delay in Minutes - 0.3%
# satisfaction - 0.0%

# %%
cols=df.columns
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sb.heatmap(df[cols].isnull(), cmap=sb.color_palette(colours))
# Out:
# <Axes: >

# %%
# Plotting a missing data histogram
# first creating missing indicator for features with missing data
for col in df.columns:
    missing = df[col].isnull()
    num_missing = np.sum(missing)
    
    if num_missing > 0:  
        print('created missing indicator for: {}'.format(col))
        df['{}_ismissing'.format(col)] = missing
#         print(missing)


# then based on the indicator, plot the histogram of missing values
ismissing_cols = [col for col in df.columns if 'ismissing' in col]
df['num_missing'] = df[ismissing_cols].sum(axis=1)

df['num_missing'].value_counts().reset_index().sort_values(by='index').plot.bar(x='index', y='num_missing')
df
# Out:
# created missing indicator for: Arrival Delay in Minutes
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13  Personal Travel
# 1                1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# ...            ...     ...     ...                ...  ...              ...
# 103899      103899   94171  Female  disloyal Customer   23  Business travel
# 103900      103900   73097    Male     Loyal Customer   49  Business travel
# 103901      103901   68825    Male  disloyal Customer   30  Business travel
# 103902      103902   54173  Female  disloyal Customer   22  Business travel
# 103903      103903   62567    Male     Loyal Customer   27  Business travel
#
#            Class  Flight Distance  Inflight wifi service  \
# 0       Eco Plus              460                      3
# 1       Business              235                      3
# 2       Business             1142                      2
# 3       Business              562                      2
# 4       Business              214                      3
# ...          ...              ...                    ...
# 103899       Eco              192                      2
# 103900  Business             2347                      4
# 103901  Business             1995                      1
# 103902       Eco             1000                      1
# 103903  Business             1723                      1
#
#         Departure/Arrival time convenient  ...  Leg room service  \
# 0                                       4  ...                 3
# 1                                       2  ...                 5
# 2                                       2  ...                 3
# 3                                       5  ...                 5
# 4                                       3  ...                 4
# ...                                   ...  ...               ...
# 103899                                  1  ...                 1
# 103900                                  4  ...                 5
# 103901                                  1  ...                 2
# 103902                                  1  ...                 5
# 103903                                  3  ...                 1
#
#         Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                      4                4                 5            5
# 1                      3                1                 4            1
# 2                      4                4                 4            5
# 3                      3                1                 4            2
# 4                      4                3                 3            3
# ...                  ...              ...               ...          ...
# 103899                 4                2                 3            2
# 103900                 5                5                 5            4
# 103901                 4                5                 5            4
# 103902                 1                5                 4            1
# 103903                 4                4                 3            1
#
#         Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0                               25                      18.0
# 1                                1                       6.0
# 2                                0                       0.0
# 3                               11                       9.0
# 4                                0                       0.0
# ...                            ...                       ...
# 103899                           3                       0.0
# 103900                           0                       0.0
# 103901                           7                      14.0
# 103902                           0                       0.0
# 103903                           0                       0.0
#
#                    satisfaction  Arrival Delay in Minutes_ismissing  \
# 0       neutral or dissatisfied                               False
# 1       neutral or dissatisfied                               False
# 2                     satisfied                               False
# 3       neutral or dissatisfied                               False
# 4                     satisfied                               False
# ...                         ...                                 ...
# 103899  neutral or dissatisfied                               False
# 103900                satisfied                               False
# 103901  neutral or dissatisfied                               False
# 103902  neutral or dissatisfied                               False
# 103903  neutral or dissatisfied                               False
#
#         num_missing
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 103899            0
# 103900            0
# 103901            0
# 103902            0
# 103903            0
#
# [103904 rows x 27 columns]

# %%
df1=df.drop(columns=['Unnamed: 0', 'id' ,'Age', 'Flight Distance', 'Inflight wifi service',
 'Departure/Arrival time convenient', 'Ease of Online booking',
 'Gate location' ,'Food and drink' ,'Online boarding', 'Seat comfort',
 'Inflight entertainment', 'On-board service', 'Leg room service',
 'Baggage handling' ,'Checkin service' ,'Inflight service' ,'Cleanliness',
 'Departure Delay in Minutes', 'Arrival Delay in Minutes'])

# %%
df1.sort_values(['satisfaction','Class']).groupby('Class').head()
# Out:
#     Gender      Customer Type   Type of Travel     Class  \
# 1     Male  disloyal Customer  Business travel  Business
# 3   Female     Loyal Customer  Business travel  Business
# 8   Female     Loyal Customer  Business travel  Business
# 28  Female     Loyal Customer  Business travel  Business
# 34    Male  disloyal Customer  Business travel  Business
# 5   Female     Loyal Customer  Personal Travel       Eco
# 6     Male     Loyal Customer  Personal Travel       Eco
# 9     Male  disloyal Customer  Business travel       Eco
# 10  Female  disloyal Customer  Business travel       Eco
# 12    Male     Loyal Customer  Business travel       Eco
# 0     Male     Loyal Customer  Personal Travel  Eco Plus
# 11  Female     Loyal Customer  Personal Travel  Eco Plus
# 37    Male     Loyal Customer  Personal Travel  Eco Plus
# 71    Male     Loyal Customer  Business travel  Eco Plus
# 73    Male     Loyal Customer  Personal Travel  Eco Plus
#
#                satisfaction  Arrival Delay in Minutes_ismissing  num_missing
# 1   neutral or dissatisfied                               False            0
# 3   neutral or dissatisfied                               False            0
# 8   neutral or dissatisfied                               False            0
# 28  neutral or dissatisfied                               False            0
# 34  neutral or dissatisfied                               False            0
# 5   neutral or dissatisfied                               False            0
# 6   neutral or dissatisfied                               False            0
# 9   neutral or dissatisfied                               False            0
# 10  neutral or dissatisfied                               False            0
# 12  neutral or dissatisfied                               False            0
# 0   neutral or dissatisfied                               False            0
# 11  neutral or dissatisfied                               False            0
# 37  neutral or dissatisfied                               False            0
# 71  neutral or dissatisfied                               False            0
# 73  neutral or dissatisfied                               False            0

# %%
df1.sort_values(['satisfaction','Class']).groupby('Class').tail()
# Out:
#         Gender      Customer Type   Type of Travel     Class satisfaction  \
# 103889  Female     Loyal Customer  Business travel  Business    satisfied
# 103891    Male     Loyal Customer  Business travel  Business    satisfied
# 103894    Male     Loyal Customer  Business travel  Business    satisfied
# 103897  Female     Loyal Customer  Business travel  Business    satisfied
# 103900    Male     Loyal Customer  Business travel  Business    satisfied
# 103858    Male     Loyal Customer  Personal Travel       Eco    satisfied
# 103859    Male     Loyal Customer  Business travel       Eco    satisfied
# 103861  Female     Loyal Customer  Business travel       Eco    satisfied
# 103872    Male     Loyal Customer  Personal Travel       Eco    satisfied
# 103887  Female     Loyal Customer  Personal Travel       Eco    satisfied
# 103674  Female     Loyal Customer  Business travel  Eco Plus    satisfied
# 103683  Female  disloyal Customer  Business travel  Eco Plus    satisfied
# 103754  Female     Loyal Customer  Business travel  Eco Plus    satisfied
# 103877    Male     Loyal Customer  Business travel  Eco Plus    satisfied
# 103890  Female     Loyal Customer  Business travel  Eco Plus    satisfied
#
#         Arrival Delay in Minutes_ismissing  num_missing
# 103889                               False            0
# 103891                               False            0
# 103894                               False            0
# 103897                               False            0
# 103900                               False            0
# 103858                               False            0
# 103859                               False            0
# 103861                               False            0
# 103872                               False            0
# 103887                               False            0
# 103674                               False            0
# 103683                               False            0
# 103754                               False            0
# 103877                               False            0
# 103890                               False            0
